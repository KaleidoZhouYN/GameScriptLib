# %%
# !pip show pytube
# Out:
# Name: pytube
# Version: 15.0.0
# Summary: Python 3 library for downloading YouTube Videos.
# Home-page: https://github.com/pytube/pytube
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\zhouy\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\zhouy\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\rich\console.py", line 1672, in print
#     with self:
#   File "C:\Users\zhouy\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\zhouy\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
# ...

# %%
from pytube import YouTube

# %%
output_path = '../resources/videos/'

# %%
yt = YouTube('https://www.youtube.com/watch?v=SC9JgsM2rgQ&list=PL1JLWArGK6Z2zyBUGsdlU8lCxLrsxwFF2&index=279')
yt = YouTube('https://www.youtube.com/watch?v=3Ma38nXugD0')
yt = YouTube('https://www.youtube.com/watch?v=1hHtF54UmQU')
yt = YouTube('https://www.youtube.com/watch?v=LFB680_JXCU')

# %%
yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first().download(output_path=output_path)
# Out:
# 'C:\\Users\\zhouy\\source\\repos\\GameScriptLib\\src\\app\\epic7\\tools\\../resources/videos/Epic Seven - Once In A Blue Moon - RTA 274.mp4'
